# %%
import seaborn as sns
import pandas as pd
import csv

# %%
j = 5
df1 = pd.read_csv('./latency_walks.csv')
df2 = pd.read_csv('./through_modified_basic.csv')
# df3 = pd.read_csv('./through_modified_FHUM.csv')
df4 = pd.read_csv('./ppa_fhum_1.csv')
df5 = pd.read_csv('./ppa_basic_1.csv')
df6 = pd.read_csv('./ppa_basic_0.csv')

# print(df2.columns)
df1.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int'})
df2.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int', 'depth' : 'int'})
# df3.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int', 'depth' : 'int'})
df4.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int'})
df5.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int'})
df6.astype({'random_string': 'str', 'graph': 'str', 'priority_nodes': 'str', 'init_bots': 'int'})
# df1 = df1
# print(df1.head)
g = 'cair'
d = 5

df11 = df1[df1['graph'] == g]
df11.rename(columns = {'parameters': 'coefficients'}, inplace = True)
df11['depth'] = d
df12 = df2[df2['graph'] == g][df2['depth'] == d]
df12.drop(columns = 'time_periods', inplace = True)
# df13 = df3[df3['graph'] == g][df3['depth'] == d]
# df13.drop(columns = 'time_periods', inplace = True)
df14 = df4[df4['graph'] == g]
df14.rename(columns = {'parameters': 'coefficients'}, inplace = True)
df14 = df14[df14['coefficients'] == '100 {}'.format(str(d))]
df15 = df5[df5['graph'] == g]
df15.rename(columns = {'parameters': 'coefficients'}, inplace = True)
df15 = df15[df15['coefficients'] == '100 {}'.format(str(d))]
df16 = df6[df6['graph'] == g]
df16.rename(columns = {'parameters': 'coefficients'}, inplace = True)
df16 = df16[df16['coefficients'] == '100 {}'.format(str(d))]
# Out:
# /tmp/ipykernel_796061/2909527955.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11.rename(columns = {'parameters': 'coefficients'}, inplace = True)
# /tmp/ipykernel_796061/2909527955.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11['depth'] = d
# /tmp/ipykernel_796061/2909527955.py:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df12 = df2[df2['graph'] == g][df2['depth'] == d]
# /tmp/ipykernel_796061/2909527955.py:25: SettingWithCopyWarning:
# ...

# %%
df21 = pd.concat([df11, df12, df16, df15, df14], axis = 0)
# df7 = pd.concat([df5, df6], axis = 0)
# df7.drop(columns = 'time_periods', inplace = True)
# print(df4.columns)
# print(df7.columns)
# df8 = pd.concat([df7, df4, df11], axis = 0)

# %%
# Out:
# No handles with labels found to put in legend.

# %%
p2 = sns.catplot(x = 'algo_name', y = 'avg_idle', data = df21, hue = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip', row = 'coefficients')
p2.figure.savefig('sim_avg_{}.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'priority_avg_idle', data = df7, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip', row = 'coefficients')
# p3.figure.savefig('prior_avg_{}.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'priority_max_idle', data = df7, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip', row = 'coefficients')
# p3.figure.savefig('prior_max_{}.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'non_priority_avg_idle', data = df7, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip', row = 'coefficients')
# p3.figure.savefig('non_priority_avg_{}.png'.format(g), bbox_inches='tight')

# p4 = sns.catplot(x = 'depth', y = 'avg_ratio', data = df7, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip', row = 'coefficients')
# p4.figure.savefig('avg_ratio_{}.png'.format(g), bbox_inches='tight')

# %%
p2 = sns.catplot(x = 'algo_name', y = 'avg_idle', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p2.set_xticklabels(rotation=30)
p2.figure.savefig('sim_avg_{}_comp.png'.format(g), bbox_inches='tight')

p3 = sns.catplot(x = 'algo_name', y = 'priority_avg_idle', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p3.set_xticklabels(rotation=30)
p3.figure.savefig('priority_avg_{}_comp.png'.format(g), bbox_inches='tight')

p4 = sns.catplot(x = 'algo_name', y = 'priority_max_idle', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p4.set_xticklabels(rotation=30)
p4.figure.savefig('priority_max_{}_comp.png'.format(g), bbox_inches='tight')

p5 = sns.catplot(x = 'algo_name', y = 'non_priority_avg_idle', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p5.set_xticklabels(rotation=30)
p5.figure.savefig('non_priority_avg_{}_comp.png'.format(g), bbox_inches='tight')

p6 = sns.catplot(x = 'algo_name', y = 'non_priority_max_idle', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p6.set_xticklabels(rotation=30)
p6.figure.savefig('non_priority_max_{}_comp.png'.format(g), bbox_inches='tight')

p7 = sns.catplot(x = 'algo_name', y = 'avg_ratio', data = df21, col = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
p7.set_xticklabels(rotation=30)
p7.figure.savefig('avg_ratio_{}_comp.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'priority_avg_idle', data = df8, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip')
# p3.figure.savefig('prior_avg_{}_comp.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'priority_max_idle', data = df8, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip')
# p3.figure.savefig('prior_max_{}_comp.png'.format(g), bbox_inches='tight')

# p3 = sns.catplot(x = 'depth', y = 'non_priority_avg_idle', data = df8, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip')
# p3.figure.savefig('non_priority_avg_{}_comp.png'.format(g), bbox_inches='tight')

# p4 = sns.catplot(x = 'depth', y = 'avg_ratio', data = df8, hue = 'init_bots', col = 'algo_name', jitter = 0.05, dodge = True, kind = 'strip')
# p4.figure.savefig('avg_ratio_{}_comp.png'.format(g), bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'depth', y = 'priority_avg_idle', data = df2, hue = 'init_bots', col = 'graph', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_prior_avg_df2.png', bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'depth', y = 'priority_avg_idle', data = df3, hue = 'init_bots', col = 'graph', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_prior_avg_df3.png', bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'graph', y = 'priority_avg_idle', data = df1, hue = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_prior_avg_df1.png', bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'graph', y = 'avg_ratio', data = df1, hue = 'init_bots', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_avg_ratio_df1.png', bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'depth', y = 'avg_ratio', data = df2, hue = 'init_bots', col = 'graph', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_avg_ratio_df2.png', bbox_inches='tight')

# %%
p3 = sns.catplot(x = 'depth', y = 'avg_ratio', data = df3, hue = 'init_bots', col = 'graph', jitter = 0.05, dodge = True, kind = 'strip')
# p2.legend(title = 'Number of Robots', bbox_to_anchor = [1.03, 1])
# p2.set_xlabel('Graph')
# p2.set_ylabel('Average Idleness')
# p2.set_title('Average Idleness for Graphs')
p3.figure.savefig('sim_avg_ratio_df3.png', bbox_inches='tight')
